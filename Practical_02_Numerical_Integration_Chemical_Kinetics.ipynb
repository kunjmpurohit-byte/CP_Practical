# %% [markdown]
# # Practical 2: Numerical Integration of Chemical Kinetics using Python Loops
#
# ### Computer Programming Lab – Chemical Engineering
# **Topic:** Looping Constructs (`for`, `while`) with Numerical Integration of Kinetics
# **Environment:** GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: How we will use AI Copilot
#
# In this practical, GitHub Copilot is your **AI coding assistant**. Use it to understand loops, numerical integration, debugging and testing.
#
# **Do not ask Copilot to write the complete practical at the beginning.** First understand the chemical equation, convert it into a numerical calculation, and decide what must be repeated. Then use Copilot for hints, explanations and debugging.
#
# At the end, you should be able to explain your own program without depending on Copilot.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Understand why loops are useful for repeated chemical-engineering calculations.
# 2. Understand the basic idea of numerical integration using small time steps.
# 3. Apply the Euler method to a simple first-order reaction.
# 4. Use a `for` loop to perform a fixed number of integration steps.
# 5. Use a `while` loop when the number of steps depends on a process condition.
# 6. Calculate concentration and conversion during a reaction.
# 7. Investigate how the time step affects the numerical result.
# 8. Use GitHub Copilot to explain, debug and improve a numerical simulation.

# %% [markdown]
# ## 2. Chemical Engineering Context
#
# Chemical engineers frequently deal with equations that describe how a quantity changes with time. For example, the concentration of a reactant in a batch reactor changes as a reaction proceeds.
#
# Consider the simple first-order reaction:
#
# ```text
# A → Products
# ```
#
# For a first-order reaction, the rate of disappearance of A can be represented by:
#
# ```text
# dC/dt = -kC
# ```
#
# where:
#
# - `C` = concentration of reactant A (mol/L)
# - `t` = time (min)
# - `k` = first-order rate constant (1/min)
#
# Instead of solving the differential equation analytically, we will use **numerical integration**. This means that we calculate the concentration step-by-step over small time intervals.
#
# **Note:** This is an educational numerical model for programming practice. It is not a substitute for a rigorous reactor-design calculation.

# %% [markdown]
# ## 3. Euler Method – The Basic Idea
#
# For a small time step `Δt`, the Euler method approximates the next concentration using:
#
# ```text
# C_new = C_old + (dC/dt) × Δt
# ```
#
# Since:
#
# ```text
# dC/dt = -kC
# ```
#
# we obtain:
#
# ```text
# C_new = C_old - k × C_old × Δt
# ```
#
# The important programming idea is that this calculation is repeated many times.

# %% [markdown]
# ## 4. Example Problem
#
# A batch reactor initially contains reactant A at:
#
# - Initial concentration: `C₀ = 1.00 mol/L`
# - Rate constant: `k = 0.05 1/min`
# - Time step: `Δt = 1 min`
# - Total simulation time: `10 min`
#
# Use the Euler method to calculate the concentration at every minute.
#
# Your program should produce a sequence similar to:
#
# ```text
# Time       Concentration
# 0          1.0000
# 1          ...
# 2          ...
# ...
# 10         ...
# ```

# %% [markdown]
# ## 5. Activity 1 – Understand What Must Be Repeated
#
# Before writing Python code, identify the repeated calculation.
#
# At every time step, you need to:
#
# 1. Calculate the rate `dC/dt`.
# 2. Calculate the change in concentration.
# 3. Calculate the new concentration.
# 4. Increase the time.
#
# ### Your task
#
# Write in your own words: **Why is a loop suitable for this problem?**

# %% [markdown]
# ### Copilot Activity 1 – Understand the Loop
#
# Ask Copilot:
#
# > I am a second-year chemical engineering student learning Python. I need to repeat an Euler-method calculation for a first-order reaction at several time steps. Explain why a for loop is suitable. Do not give me the complete program.
#
# Write one or two important points you learned from Copilot.

# %%
# Activity 1
# Print the time values from 0 to 10 minutes using a for loop.
# Write your solution here.
t=10
for i in range (t+1):
    print(f"{i} minutes")
    print("Activity 1 completed.")
# Out:
# 0 minutes
# Activity 1 completed.
# 1 minutes
# Activity 1 completed.
# 2 minutes
# Activity 1 completed.
# 3 minutes
# Activity 1 completed.
# 4 minutes
# Activity 1 completed.
# 5 minutes
# Activity 1 completed.
# 6 minutes
# Activity 1 completed.
# 7 minutes
# Activity 1 completed.
# 8 minutes
# Activity 1 completed.
# 9 minutes
# Activity 1 completed.
# 10 minutes
# Activity 1 completed.

# %% [markdown]
# ## 6. Activity 2 – Implement One Euler Integration Step
#
# Before creating a loop, implement **one** numerical integration step.
#
# Use:
#
# - `C = 1.00 mol/L`
# - `k = 0.05 1/min`
# - `dt = 1 min`
#
# Calculate:
#
# 1. Reaction rate `dC/dt`
# 2. New concentration `C_new`
#
# This helps you understand the calculation before repeating it.

# %% [markdown]
# ### Copilot Activity 2 – Ask for Explanation, Not the Answer
#
# Ask Copilot:
#
# > Explain how to translate dC/dt = -kC into one Euler integration step in Python. I want to understand the variables and sequence of calculations. Do not give me a complete simulation program.

# %%
# Activity 2
# Calculate one Euler step.
# Start with C = 1.00, k = 0.05 and dt = 1.
C=1.00
k=0.05
dt=1
dCdt=-k*C
C_new =C + dCdt
print(F"New concentration after one Euler step:{C_new:4f}")
# Out:
# New concentration after one Euler step:0.950000

# %% [markdown]
# ## 7. Activity 3 – Numerical Integration using a `for` Loop
#
# Now place the Euler calculation inside a `for` loop.
#
# Perform 10 integration steps.
#
# At each iteration:
#
# 1. Calculate `dC/dt`.
# 2. Update `C` using the Euler method.
# 3. Increase time by `dt`.
# 4. Display time and concentration.
#
# ### Important
#
# The concentration calculated in one step becomes the starting concentration for the next step.

# %% [markdown]
# ### Copilot Activity 3 – Debugging/Hint Prompt
#
# If you are stuck, ask:
#
# > I am implementing Euler integration for dC/dt = -kC inside a Python for loop. Explain what should be updated after each iteration and why. Do not write the complete code.

# %%
# Activity 3
# Use a for loop to numerically integrate the first-order reaction for 10 minutes.
C = 1.00
k = 0.05
dt = 1
t = 10
for i in range(t+1):
    # print (f"{i}minutes")
    print(f"Concentration at {i} minutes:{C:.4F}")
    C = C - k * C * dt
# Out:
# Concentration at 0 minutes:1.0000
# Concentration at 1 minutes:0.9500
# Concentration at 2 minutes:0.9025
# Concentration at 3 minutes:0.8574
# Concentration at 4 minutes:0.8145
# Concentration at 5 minutes:0.7738
# Concentration at 6 minutes:0.7351
# Concentration at 7 minutes:0.6983
# Concentration at 8 minutes:0.6634
# Concentration at 9 minutes:0.6302
# Concentration at 10 minutes:0.5987

# %% [markdown]
# ## 8. Activity 4 – Calculate Conversion
#
# For a batch reaction, conversion can be calculated as:
#
# ```text
# Conversion (%) = ((C₀ - C) / C₀) × 100
# ```
#
# Modify your simulation so that each time step displays:
#
# - Time
# - Concentration
# - Conversion
#
# Think about whether conversion should be calculated using the **initial concentration** or the current concentration.

# %% [markdown]
# ### Copilot Activity 4 – Explain Conversion
#
# Ask Copilot:
#
# > Explain how conversion is calculated from initial and current reactant concentration in a batch reactor. Explain what happens to conversion as the reactant concentration decreases. Do not write the Python program.

# %%
# Activity 4
# Add conversion (%) to your numerical integration program.
C = 1.00 
k = 0.05 
dt = 1 
t = 10 
conversion = 0.0 
for i in range(t +1 ):
    print(f"Concentration at {i} minutes: {C: .4F},Conversion: {conversion:.2f}%")
    # print (f"{i} minutes")
    dCdt = -k * C 
    C = C + dCdt * dt 
    conversion = (1- C) * 100 
print(f"Final concentration after 10 minutes: { C: .4f}")
# Out:
# Concentration at 0 minutes:  1.0000,Conversion: 0.00%
# Concentration at 1 minutes:  0.9500,Conversion: 5.00%
# Concentration at 2 minutes:  0.9025,Conversion: 9.75%
# Concentration at 3 minutes:  0.8574,Conversion: 14.26%
# Concentration at 4 minutes:  0.8145,Conversion: 18.55%
# Concentration at 5 minutes:  0.7738,Conversion: 22.62%
# Concentration at 6 minutes:  0.7351,Conversion: 26.49%
# Concentration at 7 minutes:  0.6983,Conversion: 30.17%
# Concentration at 8 minutes:  0.6634,Conversion: 33.66%
# Concentration at 9 minutes:  0.6302,Conversion: 36.98%
# Concentration at 10 minutes:  0.5987,Conversion: 40.13%
# Final concentration after 10 minutes:  0.5688

# %% [markdown]
# ## 9. Activity 5 – Numerical Integration with a `while` Loop
#
# A `for` loop is convenient when the number of integration steps is known.
#
# Now consider a different engineering requirement:
#
# > Continue the reaction simulation until conversion reaches **80%**, but stop if the simulation time reaches **100 minutes**.
#
# The number of steps is not known in advance, so a `while` loop is appropriate.
#
# Your loop should:
#
# 1. Calculate the reaction rate.
# 2. Perform one Euler step.
# 3. Update time.
# 4. Calculate conversion.
# 5. Continue while the target has not been reached and maximum time has not been exceeded.

# %% [markdown]
# ### Copilot Activity 5 – Understand `while`
#
# Ask Copilot:
#
# > Explain how to design a while-loop condition for a chemical reaction simulation that should continue until conversion reaches 80% or time reaches 100 minutes. Explain the logic without writing the complete program.

# %%
# Activity 5
# Use a while loop for the target-conversion simulation.
t =  0 
while t <= 10 : 
    print (f" {t} minutes")
    t += 1 
print ('Activity complleted')
# Out:
#  0 minutes
#  1 minutes
#  2 minutes
#  3 minutes
#  4 minutes
#  5 minutes
#  6 minutes
#  7 minutes
#  8 minutes
#  9 minutes
#  10 minutes
# Activity complleted

# %%
c = 1.00 
k = 0.05 
dt = 1 
t =0 
conversion = 0.00 
while ( conversion <=80.0 and t <= 10 ): 
    print(f"Concentration at {t} minutes: {C: .4F}, Conversion: {conversion:.2f}%")
    dCdt = -k * C 
    C = C + dCdt * dt 
    conversion = (1- C) * 100 
    t += 1
# Out:
# Concentration at 0 minutes:  0.5688, Conversion: 0.00%
# Concentration at 1 minutes:  0.5404, Conversion: 45.96%
# Concentration at 2 minutes:  0.5133, Conversion: 48.67%
# Concentration at 3 minutes:  0.4877, Conversion: 51.23%
# Concentration at 4 minutes:  0.4633, Conversion: 53.67%
# Concentration at 5 minutes:  0.4401, Conversion: 55.99%
# Concentration at 6 minutes:  0.4181, Conversion: 58.19%
# Concentration at 7 minutes:  0.3972, Conversion: 60.28%
# Concentration at 8 minutes:  0.3774, Conversion: 62.26%
# Concentration at 9 minutes:  0.3585, Conversion: 64.15%
# Concentration at 10 minutes:  0.3406, Conversion: 65.94%

# %% [markdown]
# ## 10. Activity 6 – Investigate the Effect of Time Step
#
# The Euler method is a numerical approximation. The size of `dt` can affect the result.
#
# Run the same reaction using:
#
# - `dt = 2 min`
# - `dt = 1 min`
# - `dt = 0.5 min`
# - `dt = 0.1 min`
#
# Compare the concentration obtained at approximately 10 minutes.
#
# ### Think about it
#
# Does reducing the time step make the result change? Why might a smaller time step generally give a better numerical approximation?

# %% [markdown]
# ### Copilot Activity 6 – Understand Numerical Error
#
# Ask Copilot:
#
# > Explain in beginner-friendly terms why the time-step size can affect an Euler numerical integration result. Use a first-order chemical reaction as the example. Do not provide code.

# %%
# Activity 6
# Compare Euler integration results for different dt values.
print("Activity 6: Comparing Euler integration results for different dt values")
C = 1.00
k = 0.05
dt_values = [1, 0.5, 0.1]
for dt in dt_values:
    C = 1.00  
    t = 0
    print(f"\nResults for dt = {dt}:")
    while t <= 10:
        dCdt = -k * C 
        print(f"Concentration at {t} minutes: {C:.4F}")
        dCdt = -k * C
        C = C + dCdt * dt
        t += dt
print("Activity 6 completed.")
# Out:
# Activity 6: Comparing Euler integration results for different dt values
#
# Results for dt = 1:
# Concentration at 0 minutes: 1.0000
# Concentration at 1 minutes: 0.9500
# Concentration at 2 minutes: 0.9025
# Concentration at 3 minutes: 0.8574
# Concentration at 4 minutes: 0.8145
# Concentration at 5 minutes: 0.7738
# Concentration at 6 minutes: 0.7351
# Concentration at 7 minutes: 0.6983
# Concentration at 8 minutes: 0.6634
# Concentration at 9 minutes: 0.6302
# Concentration at 10 minutes: 0.5987
#
# Results for dt = 0.5:
# Concentration at 0 minutes: 1.0000
# Concentration at 0.5 minutes: 0.9750
# Concentration at 1.0 minutes: 0.9506
# Concentration at 1.5 minutes: 0.9269
# Concentration at 2.0 minutes: 0.9037
# Concentration at 2.5 minutes: 0.8811
# Concentration at 3.0 minutes: 0.8591
# Concentration at 3.5 minutes: 0.8376
# Concentration at 4.0 minutes: 0.8167
# Concentration at 4.5 minutes: 0.7962
# Concentration at 5.0 minutes: 0.7763
# Concentration at 5.5 minutes: 0.7569
# Concentration at 6.0 minutes: 0.7380
# Concentration at 6.5 minutes: 0.7195
# Concentration at 7.0 minutes: 0.7016
# Concentration at 7.5 minutes: 0.6840
# Concentration at 8.0 minutes: 0.6669
# Concentration at 8.5 minutes: 0.6502
# Concentration at 9.0 minutes: 0.6340
# Concentration at 9.5 minutes: 0.6181
# Concentration at 10.0 minutes: 0.6027
#
# Results for dt = 0.1:
# Concentration at 0 minutes: 1.0000
# Concentration at 0.1 minutes: 0.9950
# Concentration at 0.2 minutes: 0.9900
# Concentration at 0.30000000000000004 minutes: 0.9851
# Concentration at 0.4 minutes: 0.9801
# Concentration at 0.5 minutes: 0.9752
# Concentration at 0.6 minutes: 0.9704
# Concentration at 0.7 minutes: 0.9655
# Concentration at 0.7999999999999999 minutes: 0.9607
# Concentration at 0.8999999999999999 minutes: 0.9559
# Concentration at 0.9999999999999999 minutes: 0.9511
# Concentration at 1.0999999999999999 minutes: 0.9464
# Concentration at 1.2 minutes: 0.9416
# Concentration at 1.3 minutes: 0.9369
# Concentration at 1.4000000000000001 minutes: 0.9322
# Concentration at 1.5000000000000002 minutes: 0.9276
# Concentration at 1.6000000000000003 minutes: 0.9229
# Concentration at 1.7000000000000004 minutes: 0.9183
# Concentration at 1.8000000000000005 minutes: 0.9137
# Concentration at 1.9000000000000006 minutes: 0.9092
# Concentration at 2.0000000000000004 minutes: 0.9046
# Concentration at 2.1000000000000005 minutes: 0.9001
# Concentration at 2.2000000000000006 minutes: 0.8956
# Concentration at 2.3000000000000007 minutes: 0.8911
# Concentration at 2.400000000000001 minutes: 0.8867
# Concentration at 2.500000000000001 minutes: 0.8822
# Concentration at 2.600000000000001 minutes: 0.8778
# Concentration at 2.700000000000001 minutes: 0.8734
# Concentration at 2.800000000000001 minutes: 0.8691
# Concentration at 2.9000000000000012 minutes: 0.8647
# Concentration at 3.0000000000000013 minutes: 0.8604
# Concentration at 3.1000000000000014 minutes: 0.8561
# Concentration at 3.2000000000000015 minutes: 0.8518
# Concentration at 3.3000000000000016 minutes: 0.8475
# Concentration at 3.4000000000000017 minutes: 0.8433
# Concentration at 3.5000000000000018 minutes: 0.8391
# Concentration at 3.600000000000002 minutes: 0.8349
# Concentration at 3.700000000000002 minutes: 0.8307
# Concentration at 3.800000000000002 minutes: 0.8266
# Concentration at 3.900000000000002 minutes: 0.8224
# Concentration at 4.000000000000002 minutes: 0.8183
# Concentration at 4.100000000000001 minutes: 0.8142
# Concentration at 4.200000000000001 minutes: 0.8102
# Concentration at 4.300000000000001 minutes: 0.8061
# Concentration at 4.4 minutes: 0.8021
# Concentration at 4.5 minutes: 0.7981
# Concentration at 4.6 minutes: 0.7941
# Concentration at 4.699999999999999 minutes: 0.7901
# Concentration at 4.799999999999999 minutes: 0.7862
# Concentration at 4.899999999999999 minutes: 0.7822
# Concentration at 4.999999999999998 minutes: 0.7783
# Concentration at 5.099999999999998 minutes: 0.7744
# Concentration at 5.1999999999999975 minutes: 0.7705
# Concentration at 5.299999999999997 minutes: 0.7667
# Concentration at 5.399999999999997 minutes: 0.7629
# Concentration at 5.4999999999999964 minutes: 0.7590
# Concentration at 5.599999999999996 minutes: 0.7553
# Concentration at 5.699999999999996 minutes: 0.7515
# Concentration at 5.799999999999995 minutes: 0.7477
# Concentration at 5.899999999999995 minutes: 0.7440
# Concentration at 5.999999999999995 minutes: 0.7403
# Concentration at 6.099999999999994 minutes: 0.7366
# Concentration at 6.199999999999994 minutes: 0.7329
# Concentration at 6.299999999999994 minutes: 0.7292
# Concentration at 6.399999999999993 minutes: 0.7256
# Concentration at 6.499999999999993 minutes: 0.7219
# Concentration at 6.5999999999999925 minutes: 0.7183
# Concentration at 6.699999999999992 minutes: 0.7147
# Concentration at 6.799999999999992 minutes: 0.7112
# Concentration at 6.8999999999999915 minutes: 0.7076
# Concentration at 6.999999999999991 minutes: 0.7041
# Concentration at 7.099999999999991 minutes: 0.7005
# Concentration at 7.19999999999999 minutes: 0.6970
# Concentration at 7.29999999999999 minutes: 0.6936
# Concentration at 7.39999999999999 minutes: 0.6901
# Concentration at 7.499999999999989 minutes: 0.6866
# Concentration at 7.599999999999989 minutes: 0.6832
# Concentration at 7.699999999999989 minutes: 0.6798
# Concentration at 7.799999999999988 minutes: 0.6764
# Concentration at 7.899999999999988 minutes: 0.6730
# Concentration at 7.999999999999988 minutes: 0.6696
# Concentration at 8.099999999999987 minutes: 0.6663
# Concentration at 8.199999999999987 minutes: 0.6630
# Concentration at 8.299999999999986 minutes: 0.6597
# Concentration at 8.399999999999986 minutes: 0.6564
# Concentration at 8.499999999999986 minutes: 0.6531
# Concentration at 8.599999999999985 minutes: 0.6498
# Concentration at 8.699999999999985 minutes: 0.6466
# Concentration at 8.799999999999985 minutes: 0.6433
# Concentration at 8.899999999999984 minutes: 0.6401
# Concentration at 8.999999999999984 minutes: 0.6369
# Concentration at 9.099999999999984 minutes: 0.6337
# Concentration at 9.199999999999983 minutes: 0.6306
# Concentration at 9.299999999999983 minutes: 0.6274
# Concentration at 9.399999999999983 minutes: 0.6243
# Concentration at 9.499999999999982 minutes: 0.6211
# Concentration at 9.599999999999982 minutes: 0.6180
# Concentration at 9.699999999999982 minutes: 0.6149
# Concentration at 9.799999999999981 minutes: 0.6119
# Concentration at 9.89999999999998 minutes: 0.6088
# Concentration at 9.99999999999998 minutes: 0.6058
# Activity 6 completed.

# %% [markdown]
# ## 11. Activity 7 – Compare with the Analytical Solution
#
# For a first-order reaction, the analytical solution is:
#
# ```text
# C(t) = C₀ exp(-kt)
# ```
#
# Use Python's `math.exp()` to calculate the analytical concentration at selected times.
#
# Then compare it with your Euler result.
#
# Calculate the absolute error:
#
# ```text
# Absolute Error = |Euler concentration - Analytical concentration|
# ```
#
# This activity helps you understand that numerical integration is an **approximation**.

# %% [markdown]
# ### Copilot Activity 7 – Comparison and Explanation
#
# Ask Copilot:
#
# > Explain the difference between a numerical Euler solution and the analytical solution of a first-order reaction. Why can their values be different? Do not write the complete comparison program.

# %%
# Activity 7
# Compare Euler and analytical concentrations at selected times.
print("Activity 7: Comparing Euler and analytical concentrations at selected times")
C = 1.00
k = 0.05
dt = 1
t_values = [0, 2, 4, 6, 8, 10]
for t in t_values:
    # Euler integration
    C_euler = 1.00
    for _ in range(int(t/dt)):
        dCdt = -k * C_euler
        C_euler = C_euler + dCdt * dt
    
    # Analytical solution
    C_analytical = 1.00 * (2.71828 ** (-k * t))
    
    print(f"At {t} minutes: Euler concentration = {C_euler:.4F}, Analytical concentration = {C_analytical:.4F}")
# Out:
# Activity 7: Comparing Euler and analytical concentrations at selected times
# At 0 minutes: Euler concentration = 1.0000, Analytical concentration = 1.0000
# At 2 minutes: Euler concentration = 0.9025, Analytical concentration = 0.9048
# At 4 minutes: Euler concentration = 0.8145, Analytical concentration = 0.8187
# At 6 minutes: Euler concentration = 0.7351, Analytical concentration = 0.7408
# At 8 minutes: Euler concentration = 0.6634, Analytical concentration = 0.6703
# At 10 minutes: Euler concentration = 0.5987, Analytical concentration = 0.6065

# %% [markdown]
# ## 12. Copilot Debugging Challenge
#
# The following program contains a common numerical-integration error.
#
# Study it before asking Copilot.
#
# ```python
# C = 1.0
# k = 0.05
# dt = 1.0
#
# for step in range(10):
#     rate = -k * C
#     C_new = C + rate * dt
#     print(step + 1, C)
# ```
#
# ### Your task
#
# 1. Run the program.
# 2. Look carefully at the concentration values.
# 3. Decide whether the concentration is actually being updated.
# 4. Ask Copilot:
#
# > My Euler integration program calculates C_new but the next iteration does not appear to use the new concentration. Explain the likely logic problem without rewriting the complete program.
#
# 5. Correct the program yourself.

# %%
# Run the intentionally incorrect program here.
C = 1.0
k = 0.05
dt = 1.0

for step in range(10):
    rate = -k * C
    C_new = C + rate * dt
    print(step + 1, C)
# Out:
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# 5 1.0
# 6 1.0
# 7 1.0
# 8 1.0
# 9 1.0
# 10 1.0

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 13. Testing Your Numerical Integration Program
#
# Test your program using different reaction conditions.
#
# | Test | C₀ (mol/L) | k (1/min) | dt (min) | Total Time (min) |
# |---|---:|---:|---:|---:|
# | 1 | 1.00 | 0.05 | 1.0 | 10 |
# | 2 | 2.00 | 0.02 | 1.0 | 20 |
# | 3 | 1.50 | 0.10 | 0.5 | 10 |
# | 4 | 1.00 | 0.05 | 0.1 | 10 |
# | 5 | 1.00 | 0.05 | 2.0 | 10 |
#
# For each case, record the final Euler concentration and, where possible, compare it with the analytical solution.

# %% [markdown]
# ## 14. Final Mini-Project – Batch Reaction Numerical Integrator
#
# Combine your work into one clean Python program.
#
# The final program should:
#
# 1. Accept `C₀`, `k`, `dt` and total simulation time from the user.
# 2. Validate the input values.
# 3. Numerically integrate `dC/dt = -kC` using the Euler method.
# 4. Use a loop to perform the integration steps.
# 5. Display time, concentration and conversion.
# 6. Calculate the analytical concentration using `math.exp()`.
# 7. Display the numerical error at the final time.
# 8. Clearly state that the Euler result is a numerical approximation.
#
# **Keep the program beginner-friendly. Do not use advanced libraries or techniques that have not been discussed in class.**

# %%
# FINAL PROGRAM
# Batch Reaction Numerical Integrator
# Write your clean final solution here.
import math


print("Batch Reaction Numerical Integrator")
print("Euler method for dc/dt = -kC ")
print()

while True:
    try:
        C0 = float(input("Enter initial concentration (C0) (mol\L): "))
        k = float(input("Enter rate constant k (1\min): "))
        dt = float(input("Enter time step dt (min): "))
        total_time = float(input("Enter total simulation time (min): "))
        break
    except ValueError:
        print("Invalid input. Please enter numeric values.")
        continue

    if C0 <= 0:
        print("C0 must be greater than 0.")
        continue
    if k <= 0:
        print("k must be greater than 0.")
        continue
    if dt <= 0 or total_time <= 0:
        print("dt and total_time must be positive. Please try again.")
        continue
    if total_time < dt:
        print("Total simulation time must be greater than or equal to dt. Please try again.")
        continue 

    break

C= C0
t = 0

print()
print("Time (min)  Concentration (mol\L)  Conversion (%)")
print ("-" *55)


while t <= total_time:
    conversion = ( (C0 - C) / C0) * 100
    print(f"{t:10.2f}  {C:20.4f}  {conversion:20.2f}")

    if t >= total_time:
        break   

    if t + dt > total_time:
        dt = total_time - t
    else:
        dt_step = dt

    rate = -k * C
    C = C + rate * dt_step
    t += dt_step

C_analytical = C0  *  math.exp(-k * total_time)
error = abs(C - C_analytical)
# Out:
# Batch Reaction Numerical Integrator
# Euler method for dc/dt = -kC
# <>:13: SyntaxWarning: invalid escape sequence '\L'
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:41: SyntaxWarning: invalid escape sequence '\L'
# <>:13: SyntaxWarning: invalid escape sequence '\L'
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:41: SyntaxWarning: invalid escape sequence '\L'
# /tmp/ipykernel_14852/2261372568.py:13: SyntaxWarning: invalid escape sequence '\L'
#   C0 = float(input("Enter initial concentration (C0) (mol\L): "))
# /tmp/ipykernel_14852/2261372568.py:14: SyntaxWarning: invalid escape sequence '\m'
#   k = float(input("Enter rate constant k (1\min): "))
# /tmp/ipykernel_14852/2261372568.py:41: SyntaxWarning: invalid escape sequence '\L'
#   print("Time (min)  Concentration (mol\L)  Conversion (%)")
# Time (min)  Concentration (mol\L)  Conversion (%)
# -------------------------------------------------------
#       0.00               22.0000                  0.00
#       2.00             -946.0000               4400.00

# %% [markdown]
# ## 15. Final Copilot Review
#
# After completing your final program, ask Copilot:
#
# > Review my Python Euler integration program for a first-order chemical reaction. Check whether the loop updates concentration correctly, whether the time step is used correctly, whether the stopping condition is correct, and whether the numerical result is compared properly with the analytical solution. Do not rewrite my program; identify possible issues and explain them.
#
# Make changes only after you understand the feedback.

# %% [markdown]
# ## 16. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. Why is a loop required for numerical integration?
# 2. What does `dC/dt = -kC` represent in this practical?
# 3. What does one Euler step calculate?
# 4. Why does the concentration from one step become the starting concentration for the next step?
# 5. What is the role of `dt` in numerical integration?
# 6. What did you observe when `dt` was changed?
# 7. Why can the Euler result differ from the analytical result?
# 8. What error did Copilot help you understand?
# 9. Which part of your program did you write or correct yourself after receiving a Copilot hint?
# 10. Can you explain your final program without opening Copilot?

# %% [markdown]
# ## 17. Submission Checklist
#
# - [ ] I completed all activities.
# - [ ] I used a `for` loop for numerical integration.
# - [ ] I used a `while` loop for condition-controlled integration.
# - [ ] I implemented the Euler method correctly.
# - [ ] I calculated conversion.
# - [ ] I investigated different time-step sizes.
# - [ ] I compared numerical and analytical results.
# - [ ] I calculated/observed numerical error.
# - [ ] I tested different reaction conditions.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my final program.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 18. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Basic variables and input | 1 |
# | Correct implementation of Euler step | 2 |
# | Correct use of loop for integration | 2 |
# | Conversion calculation | 1 |
# | Time-step investigation / numerical error | 1 |
# | Numerical vs analytical comparison | 1 |
# | Copilot usage and explanation | 1 |
# | Student's ability to explain/modify the program | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, change `dt` or `k` and ask the student to predict what should happen. Also ask why the concentration from the previous step is required in the next Euler calculation.
